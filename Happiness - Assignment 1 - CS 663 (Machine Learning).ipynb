# %% [markdown]
# # Happiness - Zhunan Shuai

# %% [markdown]
# # Question 1:

# %% [markdown]
# * What is your evaluation of the quality of the data?

# %%
import pandas as pd
df = pd.read_excel('DataForTable2.1WHR2023.xls')
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2199 non-null   object
#  1   year                              2199 non-null   int64
#  2   Life Ladder                       2199 non-null   float64
#  3   Log GDP per capita                2179 non-null   float64
#  4   Social support                    2186 non-null   float64
#  5   Healthy life expectancy at birth  2145 non-null   float64
#  6   Freedom to make life choices      2166 non-null   float64
#  7   Generosity                        2126 non-null   float64
#  8   Perceptions of corruption         2083 non-null   float64
#  9   Positive affect                   2175 non-null   float64
#  10  Negative affect                   2183 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479226            9.389766        0.810679
# std       4.718736     1.125529            1.153387        0.120952
# min    2005.000000     1.281271            5.526723        0.228217
# 25%    2010.000000     4.646750            8.499764        0.746609
# 50%    2014.000000     5.432437            9.498955        0.835535
# 75%    2018.000000     6.309460           10.373216        0.904792
# max    2022.000000     8.018934           11.663788        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294583                      0.747858
# std                            6.901104                      0.140150
# min                            6.720000                      0.257534
# ...

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   20
# Social support                       13
# Healthy life expectancy at birth     54
# Freedom to make life choices         33
# Generosity                           73
# Perceptions of corruption           116
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %%
df['Country name'].nunique()
# Out:
# 165

# %%
df['year'].nunique()
# Out:
# 18

# %% [markdown]
# * What is your evaluation of the quality of the data?
#     * This dataset appears to be largely complete, but there are some missing value in columns such as 'Perceptions of corruption'having the most 116 missing values, 'Generosity ', 'Healthy life expectancy at birth', 'Freedom to make life choices' etc.. missing value can impact the analysis, especially if missing values are not randomly distributed, so might need imputation or adjustment.
#     * This dataset is diversed since its includes records from 165 unique countries over 18 years, so is comprehensive in terms of country coverage spans multiple yeas, providing a robust dataset for analysis .
#     * This dataset includes a wide range of years which from year 2005 to 2022 and covers multiple variables related to happiness,  The "Life Ladder" scores range from min of 1.28 to max of 8.02 indicating a broad spectrum of happiness level that is covered.
#     * Overall, this datasethas some gaps due to missing value in columns, but appears robust for analyzing global happiness trend over time, seems approproate for variables they represent, suggesting good consistency, covers a wide range of years and includes data from numerous countries, indicating good doversity.

# %% [markdown]
# * How large is the dataset?
#   * it contains 2199 entries which represents a set of observations for a given country, and includes 11 attributes metrics. this size indicates a moderately large dataset sufficient for robust analysis and provides meanful insights.

# %% [markdown]
# * What are the features (columns) and how are they represented?
#     * Country name, Data Type: Object (String), Represents the name of the country. This is a categorical feature used to identify different nations.
#     * Year, Data Type: int64, Indicates the year of the observation.
#     * Life Ladder, Data Type: float64, Reflects the subjective well-being or happiness score
#     * Log GDP per capita:, Data Type: float64, Represents the logarithm of the GDP per capita
#     * Social support, Data Type: float64, Measures the level of social support perceived by individuals
#     * Healthy life expectancy at birth, Data Type: float64, Estimates the number of years a person is expected to live in good health
#     * Freedom to make life choices, Data Type: float64,  individuals' freedom in making life choices
#     * Generosity, Data Type: float64, Assesses the general level of generosity of a population
#     * Perceptions of corruption, Data Type: float64, Indicates the level of corruption as perceived by individuals
#     * Positive affect, Data Type: float64, Measures the average frequency and intensity of positive emotions
#     * Negative affect, Data Type: float64, Measures the average frequency and intensity of negative emotions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(ncols=4, figsize=(20,4))
sns.histplot(df['Healthy life expectancy at birth'], ax=axs[0])
sns.histplot(df['Life Ladder'], ax=axs[1])
sns.histplot(df['Log GDP per capita'], ax=axs[2])
sns.histplot(df['Freedom to make life choices'], ax=axs[3])
plt.show()

# %%
df['Healthy life expectancy at birth'].skew()
# Out:
# -1.1454543057254836

# %%
df['Healthy life expectancy at birth'].kurt()
# Out:
# 2.9896602355599575

# %% [markdown]
# * Are there any interesting distributions in the (numeric) features?
#     *  from the "Healthy life expectancy at birth", the numbers shows the distribution is skewed to the left, which make sense since its mordern world and larger number of countries have higher healthy life expectancies, with fewer countries having very low healthy life expectancies indicating many countries have made significant advances in health.
#     *  also from "Healthy life expectancy at birth" distribution graph, it indicates a leptokurtic means it porduces more outliers than expected in a normal distribution which make sense in some countries that is relatively behind should have a very low health life expectancies.

# %%
df['Freedom to make life choices'].min()
# Out:
# 0.25753381848335266

# %%
min_freedom_value = df['Freedom to make life choices'].min()
print(df[df['Freedom to make life choices'] == min_freedom_value]['Country name'])
# Out:
# 216    Bosnia and Herzegovina
# Name: Country name, dtype: object

# %% [markdown]
# * From the numeric above indicates the least number of 'Freedom to make life choices' is 0.25753381848335266 from "Bosnia and Herzegovina" which located in South Europe, this finding interests me since Europe should be a free place to make your own life choice, but the numeric indicates the opposite.

# %%
sns.scatterplot(data=df, x='Life Ladder', y='Perceptions of corruption', hue='Positive affect')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.drop(['Country name', 'Social support', 'Generosity'], axis=1).corr(), annot=True)
plt.title('Correlation Heatmap of WHR 2023 Dataset')
plt.show()

# %% [markdown]
# * Are there any interesting correlations in the data?
#     * From the scatter plot, As happiness increases (Life Ladder), the perception of corruption tends to decrease; countries with higher happiness scores generally perceive less corruption.
# There is a variation in "Positive affect" across different levels of happiness and corruption perception. Darker hues, indicating higher "Positive affect," seem to be more prevalent at higher Life Ladder scores and lower perceptions of corruption, implying that where people are happier and perceive less corruption, they also experience more positive emotion
#     * From the Heatmap, There's a strong positive correlation between 'Life Ladder' (happiness) and 'Log GDP per capita', 'Healthy life expectancy at birth', and 'Freedom to make life choices', suggesting that higher economic output, better health, and more freedom are associated with greater happiness.
#     * Also from the Heatmap, There's a strong negative correlation between 'Perceptions of corruption' and both 'Life Ladder' and 'Freedom to make life choices', indicating that higher levels of perceived corruption are linked to lower happiness and reduced freedom.s.

# %% [markdown]
# * Can you identify any limitations, missing values or distortions of the data?
#     * There is some missing values in columns data, any gaps in the dataset can lead to distortions in the correlation values. If significant portions of data are missing from any variable, the correlations can be misleading
#     * I spotted some outliers in the graph, outliers can skew correlation coefficients. If the data for any of the variables contain too many outliers, these could significantly affect the relationships, we should do some pre-processing to adjust the outliers.
#     * the data will indeed be distorted if the data collection process does not equally represent all segments of the population, the results could be skewed towards certain groups over others.

# %% [markdown]
# * What would you like to see in this dataset?
#     * I would like to see a demographic breakdown data, data on age, gender, occupation, income, education would allow for more detailed analysis of happiness across different societal groups.

# %% [markdown]
# # Question 2
# * What is the happiest country in 2022?
#     * Finland
# * What is the happiest country in 2013?
#     * Canada
# * What is the happiest country of all time?
#     * Denmark

# %%
df_2022 = df[df['year'] == 2022]
happies_country = df_2022['Life Ladder'].max()
print(df[df['Life Ladder'] == happies_country ]['Country name'])
# Out:
# 637    Finland
# Name: Country name, dtype: object

# %%
df_2013 = df[df['year'] == 2013]
happies_country = df_2013['Life Ladder'].max()
print(df[df['Life Ladder'] == happies_country ]['Country name'])
# Out:
# 334    Canada
# Name: Country name, dtype: object

# %%
happies_country = df['Life Ladder'].max()
print(df[df['Life Ladder'] == happies_country ]['Country name'])
# Out:
# 505    Denmark
# Name: Country name, dtype: object

# %% [markdown]
# * What is the least heappy country in 2022?
#     * Afghanistan
# * What is the least heappy country in 2013?
#     * Syria
# * What is the least heappy country of all time?
#     * Afghanistan

# %%
df_2022 = df[df['year'] == 2022]
least_happies_country = df_2022['Life Ladder'].min()
print(df[df['Life Ladder'] == least_happies_country ]['Country name'])
# Out:
# 13    Afghanistan
# Name: Country name, dtype: object

# %%
df_2013 = df[df['year'] == 2013]
least_happies_country = df_2013['Life Ladder'].min()
print(df[df['Life Ladder'] == least_happies_country ]['Country name'])
# Out:
# 1883    Syria
# Name: Country name, dtype: object

# %%
least_happies_country = df['Life Ladder'].min()
print(df[df['Life Ladder'] == least_happies_country ]['Country name'])
# Out:
# 13    Afghanistan
# Name: Country name, dtype: object

# %% [markdown]
# # Question 3
# * Of the countries in this dataset, which country had the largest increase in happiness from its start
# of participation to 2023?
#     * answer: Congo (Brazzaville)
# * Which had the largest decrease in happiness?
#     * answer: Lebanon

# %%
first_year_happiness = df.groupby('Country name')['Life Ladder'].first().reset_index(name='First Year Happiness')
last_year_happiness = df[df['year'] == 2022].groupby('Country name')['Life Ladder'].last().reset_index(name='Last Year Happiness')
happiness_change = pd.merge(first_year_happiness, last_year_happiness, on='Country name')
happiness_change['Happiness Change'] = happiness_change['Last Year Happiness'] - happiness_change['First Year Happiness']
largest_increase_country = happiness_change[happiness_change['Happiness Change'] == happiness_change['Happiness Change'].max()]
print(largest_increase_country[['Country name', 'Happiness Change']])
# Out:
#            Country name  Happiness Change
# 20  Congo (Brazzaville)          1.985126

# %%
first_year_happiness = df.groupby('Country name')['Life Ladder'].first().reset_index(name='First Year Happiness')
last_year_happiness = df[df['year'] == 2022].groupby('Country name')['Life Ladder'].last().reset_index(name='Last Year Happiness')
happiness_change = pd.merge(first_year_happiness, last_year_happiness, on='Country name')
happiness_change['Happiness Change'] = happiness_change['First Year Happiness'] - happiness_change['Last Year Happiness']
largest_decrease_country = happiness_change[happiness_change['Happiness Change'] == happiness_change['Happiness Change'].max()]
print(largest_decrease_country[['Country name', 'Happiness Change']])
# Out:
#    Country name  Happiness Change
# 61      Lebanon          3.138818
